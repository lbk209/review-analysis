# %%
import pandas as pd

# %%
df = pd.read_csv('reviews2.csv', header=None, names=['entity','review'])
df
# Out:
#             entity                                             review
# 0          BHC 쏘마치  BHC서현시범단지점. 근처 지점중 배달 최수 주문가가 가장 저렴해 치킨 주문. 쏘마...
# 1   처가집 양념통닭 K마라치킨   "처가집 양념통닭에서 마라치킨 주문. 그냥 달달한 양념 치킨에 마라향 살짝 추가한...
# 2         성남 버스 51        성남 51번 버스 타고 가는데 기사가 핸드폰을 보면서 운전한다. 기가 막히다.
# 3         성남 버스 51  도서관 근처에서 51번 버스를 기다리는데 정거장에 서지 않고 그냥 지나간다. 어이가...
# 4            성남 버스  분당 이마트앞 사거리에는 좌회전 신호를 놓치지 않으려는지 버스들이 전력 질주를 한다...
# 5      성남 정자동 정동마트  정자동 정동마트에서 종종 바나나 세일을 하는데 대부분 거무죽죽하니 신선도 관리를 어...
# 6             멕시카나  배달앱에서 멕시카나 치킨 할인한다기에 주문하려했더니 미금점 영업을 하지 않는다. 이...
# 7          비비큐 맵소디  비비큐에서 맵소디 배달 주문. 양념 맛은 기억나지 않지만 소스 안쪽에서도 바삭한 식...
# 8             노랑통닭  노랑통닭은 순살도 가격이 더 비싸지 않아 좋다. 튀김 부스러기는 과자같이 바삭하니 ...
# 9         푸라닭 깐풍치킨  푸라닭에서 유명 쉐프와 협업했다는 깐풍치킨 주문. 소스가 볶은 느낌이 아니라 흥건하...
# 10         교촌치킨 레드  교촌치킨에서 간장 레드 반반 주문. 간장만 먹으면 심심하고 레드만 먹으면 자극적이면...
# 11             땡겨요  예전에 땡겨요에서 세일하길래 무슨 요리 배달 주문했더니 배달에 한시간 이상 걸린다고...
# ...

# %%
import sqlite3
