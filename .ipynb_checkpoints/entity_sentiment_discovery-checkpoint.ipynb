# %% [markdown]
# # Open-Ended Review Entity & Sentiment Discovery
#
# This notebook demonstrates a first-pass approach for discovering emergent entities from free-form reviews and ranking them by aggregated sentiment. It is intentionally lightweight and assumption-driven so it can be iterated on quickly. Steps:
#
# 1. Load reviews from `reviews.csv`.
# 2. Extract candidate entities (keyphrases) per review.
# 3. Estimate sentiment per review and assign it to the entities mentioned there.
# 4. Merge semantically similar entities via embedding clustering.
# 5. Aggregate sentiments per merged entity to rank reputations.
#
# Assumptions & notes:
# - Reviews are free-form text (can be multilingual). We use keyword extraction (YAKE) instead of language-specific NER to avoid schema assumptions.
# - Sentiment is inferred at the review level with a multilingual model and propagated to its entities; per-entity sentiment extraction can be added later.
# - Semantic merging uses multilingual sentence embeddings with agglomerative clustering; adjust the distance threshold to merge more or fewer entities.

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.cluster import AgglomerativeClustering
from transformers import pipeline
import yake

pd.set_option('display.max_colwidth', None)

# %%
# Load reviews
df = pd.read_csv('reviews.csv', header=None, names=['review_text'])
df.head()
# Out:
#                                                                                                                                                review_text
# 0  BHC서현시범단지점. 근처 지점중 배달 최수 주문가가 가장 저렴해 치킨 주문. 쏘마치를 주문하려니 배달하기 천원이 모자라 마늘 토핑 추가 주문. 배달 받고 보니 서비스라고 콜라까지 보냈다. 따로 리뷰 요청도 없었는데. 마늘 토핑은 안쪽까지 바삭하니 과자 식감이 신기했다.
# 1                                                                                  처가집 양념통닭에서 마라치킨 주문. 그냥 달달한 양념 치킨에 마라향 살짝 추가한 정도. 닭고기 모든 부위 식감이 퍽퍽한것 같다.
# 2                                                                                                              성남 51번 버스 타고 가는데 기사가 핸드폰을 보면서 운전한다. 기가 막히다.
# 3                                                                                                       도서관 근처에서 51번 버스를 기다리는데 정거장에 서지 않고 그냥 지나간다. 어이가 없다.
# 4                                                                       분당 이마트앞 사거리에는 좌회전 신호를 놓치지 않으려는지 버스들이 전력 질주를 한다. 무섭다. 거기 우회전할때도 길건너는 사람 치지 않을지 두렵다.

# %%
# Extract candidate entities/keyphrases per review using YAKE

# YAKE works well for short documents; tune max_ngram_size to control phrase length
kw_extractor = yake.KeywordExtractor(lan='multi', n=3, top=5)

entity_rows = []
for idx, row in df.iterrows():
    text = str(row['review_text'])
    keywords = kw_extractor.extract_keywords(text)
    # keywords returns list of (phrase, score); lower score = more relevant
    for phrase, score in keywords:
        cleaned = phrase.strip().lower()
        if cleaned:
            entity_rows.append({'review_id': idx, 'entity': cleaned, 'yake_score': score})

entities_df = pd.DataFrame(entity_rows)
entities_df.head()
# Out:
#    review_id       entity  yake_score
# 0          0  bhc 서현시범단지점    0.011416
# 1          0          bhc    0.073519
# 2          0      서현시범단지점    0.153531
# 3          0  주문가가 가장 저렴해    0.387110
# 4          0   쏘마치를 주문하려니    0.421891

# %%
# Sentiment analysis per review (multilingual). The model outputs 1-5 stars.
sentiment_model = pipeline('sentiment-analysis', model='nlptown/bert-base-multilingual-uncased-sentiment')

sentiment_rows = []
for idx, row in df.iterrows():
    text = str(row['review_text'])
    result = sentiment_model(text)[0]
    # label is like '4 stars'; convert to int
    stars = int(result['label'].split()[0])
    sentiment_rows.append({'review_id': idx, 'sentiment_score': stars, 'sentiment_label': result['label'], 'sentiment_confidence': result['score']})

sentiment_df = pd.DataFrame(sentiment_rows)
sentiment_df.head()
# Out:
# config.json:   0%|          | 0.00/953 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/669M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cpu
#    review_id  sentiment_score sentiment_label  sentiment_confidence
# 0          0                1          1 star              0.366525
# 1          1                2         2 stars              0.401091
# 2          2                2         2 stars              0.395894
# 3          3                1          1 star              0.391639
# 4          4                1          1 star              0.421016

# %%
# Merge entity mentions with review-level sentiment
mentions_df = entities_df.merge(sentiment_df[['review_id', 'sentiment_score']], on='review_id', how='left')
mentions_df.head()
# Out:
#    review_id       entity  yake_score  sentiment_score
# 0          0  bhc 서현시범단지점    0.011416                1
# 1          0          bhc    0.073519                1
# 2          0      서현시범단지점    0.153531                1
# 3          0  주문가가 가장 저렴해    0.387110                1
# 4          0   쏘마치를 주문하려니    0.421891                1

# %%
# Embed entities and cluster to merge similar mentions
# Using a multilingual model to capture cross-language similarity
embedder = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

unique_entities = mentions_df['entity'].unique().tolist()
embeddings = embedder.encode(unique_entities, convert_to_tensor=False)

# Clustering: distance_threshold controls how aggressively we merge (lower = stricter)
# Adjust 'distance_threshold' after inspecting results.
clustering = AgglomerativeClustering(
    n_clusters=None,
    metric='cosine',
    linkage='average',
    distance_threshold=0.35,
)
labels = clustering.fit_predict(embeddings)

cluster_map = {
    entity: f"cluster_{label}"
    for entity, label in zip(unique_entities, labels)
}

mentions_df['entity_cluster'] = mentions_df['entity'].map(cluster_map)
mentions_df.head()
# Out:
#    review_id       entity  yake_score  sentiment_score entity_cluster
# 0          0  bhc 서현시범단지점    0.011416                1      cluster_3
# 1          0          bhc    0.073519                1      cluster_1
# 2          0      서현시범단지점    0.153531                1      cluster_3
# 3          0  주문가가 가장 저렴해    0.387110                1      cluster_2
# 4          0   쏘마치를 주문하려니    0.421891                1      cluster_2

# %%
# Aggregate sentiment per merged entity cluster
entity_stats = (
    mentions_df
    .groupby('entity_cluster')
    .agg(
        n_mentions=('entity', 'count'),
        unique_entities=('entity', lambda x: sorted(set(x))),
        mean_sentiment=('sentiment_score', 'mean'),
        median_sentiment=('sentiment_score', 'median'),
    )
    .reset_index()
    .sort_values(by='mean_sentiment', ascending=False)
)

entity_stats
# Out:
#    entity_cluster  n_mentions  \
# 5      cluster_13           1
# 13      cluster_8           1
# 14      cluster_9           1
# 4      cluster_12           2
# 11      cluster_6          14
# 7       cluster_2          98
# 0       cluster_0           2
# 1       cluster_1           2
# 10      cluster_5           4
# 2      cluster_10           2
# 3      cluster_11           1
# 6      cluster_14           2
# 8       cluster_3           2
# 9       cluster_4           2
# 12      cluster_7           1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        unique_entities  \
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [좋아하는 고추바사삭]
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [쉐프와 협업했다는]
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [현대시장]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [비비큐에서, 비비큐에서 맵소디]
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [교촌치킨에서, 노랑통닭은, 노랑통닭은 순살도, 노랑통닭은 순살도 가격이, 닭강정 사는걸, 닭강정 사는걸 깜빡했다, 양념통닭에서, 양념통닭에서 마라치킨, 처가집, 처가집 양념통닭에서, 처가집 양념통닭에서 마라치킨, 푸라닭에서, 푸라닭에서 유명 쉐프와, 한동안 집앞 자담치킨]
# 7   [가격이 더 비싸지, 가는데 기사가, 가는데 기사가 핸드폰을, 간만에 접속해, 간장만 먹으면, 간장만 먹으면 심심하고, 감흥이 덜하다, 갔다가 얼떨결에 비급여, 거무죽죽하니 신선도 관리를, 검색하려고 카카오맵을 켰더니, 결재하고 며칠뒤 배송을, 광고부터 나온다, 구경하고 돌아가는, 굽네치킨에서 유일하게, 굽네치킨에서 유일하게 좋아하는, 귀한족발에서 족발 배달시켰는데, 기다리는데 정거장에, 기사가 핸드폰을 보면서, 기억한다, 느껴진건 기억한다, 니자도 발뒤꿈치가, 대부분 거무죽죽하니 신선도, 땡겨요에서 세일하길래, 땡겨요에서 할인을, 마트에서, 마트에서 풀무원, 마트에서 풀무원 감자전/오징어부추전, 막국수 반찬까지 있는건, 많이도 포장해 먹었다, 맞은데를 피해서, 맵소디, 먹었는데 감흥이 덜하다, 먹으면, 먹으면 심심하고 레드만, 멕시칸 치킨 할인한다기에, 며칠뒤 배송을 기다리는데, 며칠이 니자도, 며칠이 니자도 발뒤꿈치가, 명성왕족발에서, 민생지원금으로, 민생지원금으로 성남 할머니, 바나나 세일을 하는데, 반찬까지 있는건 좋지만, 발가락이 아파서, 발뒤꿈치가 아파 미금역, 발뒤꿈치가 아파 정형외과를, 배달시켰는데 막국수 반찬까지, 보면서 운전한다, 사는걸 깜빡했다, 설치해야 이용할수 있다고, 세일을 하는데 대부분, 세일한다기에, 속초에서 시장 구경하고, 순살도 가격이, 쉐프와 협업했다는 깐풍치킨, 시키고 하나만 받으러, 신호를 놓치지 않으려는지, 쏘마치를 주문하려니, 아파서 동네 정형외과, 안된다, 언제부터인가, 얼떨결에 비급여, 영업을 하지 않는다, 예전에 땡겨요에서, 예전에 땡겨요에서 세일하길래, 유일하게 좋아하는, 유일하게 좋아하는 고추바사삭, 이마트, 자담치킨 참 많이도, 접속이, 접속이 안된다, 접속해 보니 티머니매니저를, 정형외과 갔다가 얼떨결에, 정형외과를 찾는데, 정형외과를 찾는데 저번에, 정형외과를 찾아갔다, 족발맛이 아쉽다, 족발에서, 좌회전 신호를 놓치지, 주문가가 가장 저렴해, 주문하려했더니 미금점 영업을, 주문했더니 배달에, 주문했더니 배달에 한시간, 찾는데 저번에, 치약이었다, 카카오맵을 켰더니 광고부터, 켰더니 광고부터 나온다, 티머니매니저를 추가 설치해야, 포장해 먹었다, 풀무원, 풀무원 감자전/오징어부추전, 하나만 받으러 오라고, 하는데 대부분 거무죽죽하니, 한셋트 치약이었다, 할인한다기에 주문하려했더니 미금점, 핸드폰을 보면서 운전한다, 현대시장 명성왕족발에서, 협업했다는 깐풍치킨]
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [모바일 티머니, 홈플러스 앱으로]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [bhc, 한셋트]
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [급하게 버스 검색하려고, 놓치지 않으려는지 버스들이, 버스를 기다리는데, 버스를 기다리는데 정거장에]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [할머니, 할머니 족발에서]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [하나은행]
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [도서관, 도서관 근처에서]
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [bhc 서현시범단지점, 서현시범단지점]
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [사거리에는 좌회전 신호를, 이마트앞 사거리에는 좌회전]
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [배달앱에서 멕시칸]
#
#     mean_sentiment  median_sentiment
# 5         5.000000               5.0
# 13        5.000000               5.0
# 14        4.000000               4.0
# 4         3.000000               3.0
# 11        2.357143               2.0
# 7         2.153061               2.0
# 0         1.500000               1.5
# 1         1.500000               1.5
# 10        1.250000               1.0
# 2         1.000000               1.0
# 3         1.000000               1.0
# 6         1.000000               1.0
# 8         1.000000               1.0
# 9         1.000000               1.0
# 12        1.000000               1.0

# %%
entity_stats.to_csv('entity_stats.csv')

# %% [markdown]
# ## Next steps
# - Improve entity extraction with language-specific tokenizers or NER models if the data distribution is known.
# - Move from review-level to entity-level sentiment by pairing entity spans with sentence-level sentiment.
# - Experiment with different clustering thresholds or algorithms (e.g., HDBSCAN) to better control entity merging.
# - Persist intermediate artifacts (embeddings, clusters) for incremental updates on new reviews.
